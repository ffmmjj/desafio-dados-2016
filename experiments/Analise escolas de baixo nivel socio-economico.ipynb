# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../')

# %%
from src.carregamento.dados import escolas_nse_baixo

# %%
plot = plt.plot(sorted(escolas_nse_baixo.MEDIA_9EF_MT.values))
plt.ylim(150, 400)
plt.show()

# %%
plot = plt.plot(sorted(escolas_nse_alto.MEDIA_9EF_MT.values))
plt.ylim(150, 400)
plt.show()

# %%
from src.carregamento.dados import escolas_nse_alto

# %%
plt.hist(escolas_nse_baixo.MEDIA_9EF_MT.values)
plt.show()

# %%
plt.hist(escolas_nse_alto.MEDIA_9EF_MT.values)
plt.show()
